# %% [markdown]
# <a href="https://colab.research.google.com/github/gsgit12345/demo-project-pytorch-tutorial/blob/release%2F0.1/second.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/gsgit12345/demo-project-pytorch-tutorial.git
# !git config --global user.email "gsgmca682@gmail.com"
# !git config --global user.name "ghanshyam shukla"
# !cd demo-project-pytorch-tutorial
# Out:
# fatal: destination path 'demo-project-pytorch-tutorial' already exists and is not an empty directory.

# %%
# !git config --global user.email "gsgmca682@gmail.com"
# !git config --global user.name "ghanshyam shukla"
# !cd demo-project-pytorch-tutorial
